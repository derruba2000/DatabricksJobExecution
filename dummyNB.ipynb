# %%
# %run ./util

# %%
SleepTimeS=int(dbutils.widgets.get('SleepTimeS'))
DurationTimeS=int(dbutils.widgets.get('DurationTimeS'))

# %%
dateInit=datetime.now()
while (dateInit + timedelta(seconds=DurationTimeS) > datetime.now()):
            LogMsg="{0}: Executing dummy notebook...".format(GETDATE())
            print(LogMsg)
            time.sleep(SleepTimeS)
print("{0}: Dummy notebook executed!".format(GETDATE()))
